# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-Kasper/is310-final-project-leo-kasper/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import nltk
from nltk import word_tokenize
from nltk import FreqDist
from nltk.stem import PorterStemmer
porter = PorterStemmer()
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import warnings

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ZoeLeBlanc/visualizing_humanities_data_workshop/master/web_scraped_humanist_listserv.csv")

# %%
# !pip3 install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
df = df.iloc[:21]

# %%
df
# Out:
#         dates                                               text
# 0   1987-1988  From: MCCARTY@UTOREPAS\nSubject: \nDate: 12 Ma...
# 1   1988-1989  From: Sebastian Rahtz \nSubject: C++ and Gnu o...
# 2   1989-1990  From: Willard McCarty \nSubject: Happy Birthda...
# 3   1990-1991  From: Elaine Brennan & Allen Renear \nSubject:...
# 4   1991-1992  From: Elaine Brennan & Allen Renear \nSubject:...
# 5   1992-1993  From: Elaine M Brennan \nSubject: Humanist's B...
# 6   1993-1994  From: 6500card%ucsbuxa@hub.ucsb.edu (Cheryl A....
# 7   1994-1995  From: Andrew Burday \nSubject: Re: 7.0638 Qs: ...
# 8   1995-1996  From: "Gregory Bloomquist" \nSubject: Round Ta...
# 9   1996-1997  From: Humanist \nSubject: Humanist begins its ...
# 10  1997-1998  From: Willard McCarty \nSubject: mind no mind\...
# 11  1998-1999  From: Willard McCarty \nSubject: one more than...
# 12  1999-2000  From: Willard McCarty \nSubject: HAPPY now we ...
# 13  2000-2001  From: Willard McCarty \nSubject: HAPPY now we ...
# 14  2001-2002  From: Willard McCarty \nSubject: 14\nDate: Mon...
# 15  2002-2003  From: NINCH-ANNOUNCE \nSubject: New Project: "...
# 16  2003-2004  From: Willard McCarty \nSubject: Happy Sweet 1...
# 17  2004-2005  From: Willard McCarty \nSubject: happy 17th bi...
# 18  2005-2006  From: Willard McCarty \nSubject: Happy 18th bi...
# 19  2006-2007  From: Willard McCarty \nSubject: Happy 19th bi...
# 20  2007-2008  From: Willard McCarty \nSubject: Humanist's 20...

# %%
df['start_yr'] = df['dates'].str.split('-').str[0]
df['end_yr'] = df['dates'].str.split('-').str[1]
df['vol_size'] = df['text'].str.count('\n')

# %%
df
# Out:
#         dates                                               text start_yr  \
# 0   1987-1988  From: MCCARTY@UTOREPAS\nSubject: \nDate: 12 Ma...     1987
# 1   1988-1989  From: Sebastian Rahtz \nSubject: C++ and Gnu o...     1988
# 2   1989-1990  From: Willard McCarty \nSubject: Happy Birthda...     1989
# 3   1990-1991  From: Elaine Brennan & Allen Renear \nSubject:...     1990
# 4   1991-1992  From: Elaine Brennan & Allen Renear \nSubject:...     1991
# 5   1992-1993  From: Elaine M Brennan \nSubject: Humanist's B...     1992
# 6   1993-1994  From: 6500card%ucsbuxa@hub.ucsb.edu (Cheryl A....     1993
# 7   1994-1995  From: Andrew Burday \nSubject: Re: 7.0638 Qs: ...     1994
# 8   1995-1996  From: "Gregory Bloomquist" \nSubject: Round Ta...     1995
# 9   1996-1997  From: Humanist \nSubject: Humanist begins its ...     1996
# 10  1997-1998  From: Willard McCarty \nSubject: mind no mind\...     1997
# 11  1998-1999  From: Willard McCarty \nSubject: one more than...     1998
# 12  1999-2000  From: Willard McCarty \nSubject: HAPPY now we ...     1999
# 13  2000-2001  From: Willard McCarty \nSubject: HAPPY now we ...     2000
# 14  2001-2002  From: Willard McCarty \nSubject: 14\nDate: Mon...     2001
# 15  2002-2003  From: NINCH-ANNOUNCE \nSubject: New Project: "...     2002
# 16  2003-2004  From: Willard McCarty \nSubject: Happy Sweet 1...     2003
# 17  2004-2005  From: Willard McCarty \nSubject: happy 17th bi...     2004
# 18  2005-2006  From: Willard McCarty \nSubject: Happy 18th bi...     2005
# 19  2006-2007  From: Willard McCarty \nSubject: Happy 19th bi...     2006
# 20  2007-2008  From: Willard McCarty \nSubject: Humanist's 20...     2007
#
#    end_yr  vol_size
# 0    1988     50794
# 1    1989     36109
# 2    1990    108695
# 3    1991    118929
# 4    1992     81193
# 5    1993     59957
# 6    1994     71763
# 7    1995     46569
# 8    1996     61076
# 9    1997     52506
# 10   1998     89100
# 11   1999     70304
# 12   2000     72641
# 13   2001     89197
# 14   2002     85729
# 15   2003     80589
# 16   2004     95265
# 17   2005     55776
# 18   2006     53619
# 19   2007     44493
# 20   2008     38994

# %%
def stem_words(row):
    stemmed_words = ''
    for token in row.text.split(' '):
        stemmed_words += porter.stem(token) + ' '
    return stemmed_words

# %%
df['stemmed_text'] = df.apply(stem_words,axis=1)

# %%
df
# Out:
#         dates                                               text start_yr  \
# 0   1987-1988  From: MCCARTY@UTOREPAS\nSubject: \nDate: 12 Ma...     1987
# 1   1988-1989  From: Sebastian Rahtz \nSubject: C++ and Gnu o...     1988
# 2   1989-1990  From: Willard McCarty \nSubject: Happy Birthda...     1989
# 3   1990-1991  From: Elaine Brennan & Allen Renear \nSubject:...     1990
# 4   1991-1992  From: Elaine Brennan & Allen Renear \nSubject:...     1991
# 5   1992-1993  From: Elaine M Brennan \nSubject: Humanist's B...     1992
# 6   1993-1994  From: 6500card%ucsbuxa@hub.ucsb.edu (Cheryl A....     1993
# 7   1994-1995  From: Andrew Burday \nSubject: Re: 7.0638 Qs: ...     1994
# 8   1995-1996  From: "Gregory Bloomquist" \nSubject: Round Ta...     1995
# 9   1996-1997  From: Humanist \nSubject: Humanist begins its ...     1996
# 10  1997-1998  From: Willard McCarty \nSubject: mind no mind\...     1997
# 11  1998-1999  From: Willard McCarty \nSubject: one more than...     1998
# 12  1999-2000  From: Willard McCarty \nSubject: HAPPY now we ...     1999
# 13  2000-2001  From: Willard McCarty \nSubject: HAPPY now we ...     2000
# 14  2001-2002  From: Willard McCarty \nSubject: 14\nDate: Mon...     2001
# 15  2002-2003  From: NINCH-ANNOUNCE \nSubject: New Project: "...     2002
# 16  2003-2004  From: Willard McCarty \nSubject: Happy Sweet 1...     2003
# 17  2004-2005  From: Willard McCarty \nSubject: happy 17th bi...     2004
# 18  2005-2006  From: Willard McCarty \nSubject: Happy 18th bi...     2005
# 19  2006-2007  From: Willard McCarty \nSubject: Happy 19th bi...     2006
# 20  2007-2008  From: Willard McCarty \nSubject: Humanist's 20...     2007
#
#    end_yr  vol_size                                       stemmed_text
# 0    1988     50794  from: mccarty@utorepas\nsubject: \ndate: 12 ma...
# 1    1989     36109  from: sebastian rahtz \nsubject: c++ and gnu o...
# 2    1990    108695  from: willard mccarti \nsubject: happi birthda...
# 3    1991    118929  from: elain brennan & allen renear \nsubject: ...
# 4    1992     81193  from: elain brennan & allen renear \nsubject: ...
# 5    1993     59957  from: elain M brennan \nsubject: humanist' bir...
# 6    1994     71763  from: 6500card%ucsbuxa@hub.ucsb.edu (cheryl A....
# 7    1995     46569  from: andrew burday \nsubject: re: 7.0638 qs: ...
# 8    1996     61076  from: "gregori bloomquist" \nsubject: round ta...
# 9    1997     52506  from: humanist \nsubject: humanist begin it 10...
# 10   1998     89100  from: willard mccarti \nsubject: mind no mind\...
# 11   1999     70304  from: willard mccarti \nsubject: one more than...
# 12   2000     72641  from: willard mccarti \nsubject: happi now we ...
# 13   2001     89197  from: willard mccarti \nsubject: happi now we ...
# 14   2002     85729  from: willard mccarti \nsubject: 14\ndate: mon...
# 15   2003     80589  from: ninch-announc \nsubject: new project: "a...
# 16   2004     95265  from: willard mccarti \nsubject: happi sweet 1...
# 17   2005     55776  from: willard mccarti \nsubject: happi 17th bi...
# 18   2006     53619  from: willard mccarti \nsubject: happi 18th bi...
# 19   2007     44493  from: willard mccarti \nsubject: happi 19th bi...
# 20   2008     38994  from: willard mccarti \nsubject: humanist' 20t...

# %%
documents = df.text.tolist()
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
vectorizer = TfidfVectorizer(max_df=0.5, min_df=1,stop_words=stop_words)

# %%
transformed_documents = vectorizer.fit_transform(documents)

transformed_documents_as_array = transformed_documents.toarray()

dates = df.dates.tolist()
tfidf_results = []
for counter, doc in enumerate(transformed_documents_as_array):
    tf_idf_tuples = list(zip(vectorizer.get_feature_names(), doc))
    one_doc_as_df = pd.DataFrame.from_records(tf_idf_tuples, columns=['term', 'score']).sort_values(by='score', ascending=False).reset_index(drop=True)
    one_doc_as_df['dates'] = dates[counter]
    tfidf_results.append(one_doc_as_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
warnings.filterwarnings("ignore")

# %%
tfidf_df = pd.concat(tfidf_results)
tfidf_df = tfidf_df.sort_values(by=['score'], ascending=False)
tfidf_df.head()
# Out:
#        term     score      dates
# 0     ninch  0.841249  2002-2003
# 0     ninch  0.822897  2000-2001
# 0     ninch  0.790522  2001-2002
# 0  utorepas  0.766377  1987-1988
# 0     ninch  0.671890  1999-2000

# %%
tfidf_df.term.unique()
tfidf_df['start_yr'] = tfidf_df['dates'].str.split('-').str[0].astype(int)
tfidf_df['end_yr'] = tfidf_df['dates'].str.split('-').str[1].astype(int)
tfidf_df
# Out:
#             term     score      dates  start_yr  end_yr
# 0          ninch  0.841249  2002-2003      2002    2003
# 0          ninch  0.822897  2000-2001      2000    2001
# 0          ninch  0.790522  2001-2002      2001    2002
# 0       utorepas  0.766377  1987-1988      1987    1988
# 0          ninch  0.671890  1999-2000      1999    2000
# ...          ...       ...        ...       ...     ...
# 65250       saab  0.000000  1994-1995      1994    1995
# 65251    s782293  0.000000  1994-1995      1994    1995
# 65252         s6  0.000000  1994-1995      1994    1995
# 65253        s6b  0.000000  1994-1995      1994    1995
# 154348  žikovský  0.000000  2007-2008      2007    2008
#
# [3241329 rows x 5 columns]

# %%
#Top 10 unique words for all data
top10_all = tfidf_df.drop_duplicates(subset = 'term', keep = 'first').head(10)
top10_all
# Out:
#         term     score      dates  start_yr  end_yr
# 0      ninch  0.841249  2002-2003      2002    2003
# 0   utorepas  0.766377  1987-1988      1987    1988
# 1      amico  0.444180  1999-2000      1999    2000
# 0        fqs  0.426306  2005-2006      2005    2006
# 0   wmccarty  0.384587  2007-2008      2007    2008
# 1      fludd  0.337311  2007-2008      2007    2008
# 0     google  0.333120  2004-2005      2004    2005
# 1       elra  0.321378  1997-1998      1997    1998
# 1  wikipedia  0.316421  2005-2006      2005    2006
# 0       7848  0.301380  2003-2004      2003    2004

# %%
import altair as alt
alt.renderers.enable('default')
alt.data_transformers.enable('default', max_rows=None)
# Out:
# DataTransformerRegistry.enable('default')

# %%
#Part 1

alt.Chart(top10_all).mark_bar().encode(
    alt.X('term'),
    alt.Y('score'),
    color=alt.Color('term', scale=alt.Scale(scheme='accent'), sort=alt.Sort()),
)
# Out:
# alt.Chart(...)

# %%
#Part 2


alt.Chart(tfidf_df).mark_bar().encode(
    x='dates',
    y='score',
    color=alt.Color('term', scale=alt.Scale(scheme='accent'), sort=alt.Sort()),
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-9c42ca111138> in <module>()
#       3     x='dates',
#       4     y='score',
# ----> 5     color=alt.Color('term', scale=alt.Scale(scheme='accent'), sort=alt.Sort()),
#       6 )
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/displayhook.py in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     148
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     # This can be set to True by the write_output_prompt method in a subclass
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     150             return {}, {}
#     151
# --> 152         format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#     153
#     154         if format_dict or md_dict:
#
# <decorator-gen-5> in __call__(self, obj, include, exclude)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968                 d['include'] = include
#     969                 d['exclude'] = exclude
# --> 970                 return method(**d)
#     971             return None
#     972         else:
#
# /usr/local/lib/python3.7/dist-packages/altair/vegalite/v4/api.py in _repr_mimebundle_(self, include, exclude)
#    1672         # see https://github.com/ipython/ipython/issues/11038
#    1673         try:
# -> 1674             dct = self.to_dict()
#    1675         except Exception:
#    1676             utils.display_traceback(in_ipython=True)
#
# /usr/local/lib/python3.7/dist-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#    2018             copy.data = core.InlineData(values=[{}])
#    2019             return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020         return super().to_dict(*args, **kwargs)
#    2021
#    2022     def add_selection(self, *selections):
#
# /usr/local/lib/python3.7/dist-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     372         copy = self.copy(deep=False)
#     373         original_data = getattr(copy, "data", Undefined)
# --> 374         copy.data = _prepare_data(original_data, context)
#     375
#     376         if original_data is not Undefined:
#
# /usr/local/lib/python3.7/dist-packages/altair/vegalite/v4/api.py in _prepare_data(data, context)
#      87     # convert dataframes  or objects with __geo_interface__ to dict
#      88     if isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# ---> 89         data = _pipe(data, data_transformers.get())
#      90
#      91     # convert string input to a URLData
#
# /usr/local/lib/python3.7/dist-packages/toolz/functoolz.py in pipe(data, *funcs)
#     628     """
#     629     for func in funcs:
# --> 630         data = func(data)
#     631     return data
#     632
#
# /usr/local/lib/python3.7/dist-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     304     def __call__(self, *args, **kwargs):
#     305         try:
# --> 306             return self._partial(*args, **kwargs)
#     307         except TypeError as exc:
#     308             if self._should_curry(args, kwargs, exc):
#
# /usr/local/lib/python3.7/dist-packages/altair/vegalite/data.py in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#      20
#      21
#
# /usr/local/lib/python3.7/dist-packages/toolz/functoolz.py in pipe(data, *funcs)
#     628     """
#     629     for func in funcs:
# --> 630         data = func(data)
#     631     return data
#     632
#
# /usr/local/lib/python3.7/dist-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     304     def __call__(self, *args, **kwargs):
#     305         try:
# --> 306             return self._partial(*args, **kwargs)
#     307         except TypeError as exc:
#     308             if self._should_curry(args, kwargs, exc):
#
# /usr/local/lib/python3.7/dist-packages/altair/utils/data.py in to_values(data)
#     148     elif isinstance(data, pd.DataFrame):
#     149         data = sanitize_dataframe(data)
# --> 150         return {"values": data.to_dict(orient="records")}
#     151     elif isinstance(data, dict):
#     152         if "values" not in data:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in to_dict(self, orient, into)
#    1821             )
#    1822             return [
# -> 1823                 into_c((k, maybe_box_native(v)) for k, v in row.items()) for row in rows
#    1824             ]
#    1825
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in <listcomp>(.0)
#    1821             )
#    1822             return [
# -> 1823                 into_c((k, maybe_box_native(v)) for k, v in row.items()) for row in rows
#    1824             ]
#    1825
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in <genexpr>(.0)
#    1817             columns = self.columns.tolist()
#    1818             rows = (
# -> 1819                 dict(zip(columns, row))
#    1820                 for row in self.itertuples(index=False, name=None)
#    1821             )
#
# KeyboardInterrupt:

# %%
alt.Chart(top10_all).mark_bar().encode(
    x='dates',
    y='score',
    color=alt.Color('term', scale=alt.Scale(scheme='accent'), sort=alt.Sort()),
)
# Out:
# alt.Chart(...)
